# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
data1=pd.read_csv('./流水销售记录1.csv',encoding='gbk',header='infer')
data2=pd.read_csv('./流水销售记录2.csv',encoding='gbk',header='infer')
print(data1)
print(data2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import warnings
#       3 warnings.filterwarnings('ignore')
# ----> 4 data1=pd.read_csv('./流水销售记录1.csv',encoding='gbk',header='infer')
#       5 data2=pd.read_csv('./流水销售记录2.csv',encoding='gbk',header='infer')
#       6 print(data1)
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\io\parsers\readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File c:\plugins\python\python3.8.5\lib\site-packages\pandas\io\common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './流水销售记录1.csv'

# %%
data=pd.merge(data1,data2,on='商品')
print(data)
# Out:
#                                    订单号             设备ID 应付金额 实际金额  \
# 0        DD201708167493663618499909784  E43A6E078A07631       4.5
# 1         DD20170816749368329675770932  E43A6E078A07631  4.5  4.5
# 2      DD20170816749300229112037656709  E43A6E078A06874  4.5  4.5
# 3        DD201708167493529849068514902  E43A6E078A04228    4    4
# 4        DD201708167493876353091909391  E43A6E078A04228   14   14
# ...                                ...              ...  ...  ...
# 70685    DD201708167493878114605918673  E43A6E078A04228   11   11
# 70686    DD201708167493690426013200961  E43A6E078A04228    4    4
# 70687    DD201708167493774605081730209  E43A6E078A04172   11   11
# 70688    DD2017041716541957D1BE9289A69  E43A6E078A04228  0.1  0.1
# 70689    DD2017041716040483BC6D38F8F83  E43A6E078A06874  0.1  0.1
#
#                  商品              支付时间 地点      状态   提现   大类    二级类
# 0      68g好丽友巧克力派2枚     2017/1/1 0:53  D  已出货未退款  已提现  非饮料   饼干糕点
# 1      68g好丽友巧克力派2枚    2017/1/2 20:58  D  已出货未退款  已提现  非饮料   饼干糕点
# 2      68g好丽友巧克力派2枚     2017/1/3 1:53  E  已出货未退款  已提现  非饮料   饼干糕点
# 3      68g好丽友巧克力派2枚    2017/1/8 20:22  C  已出货未退款  已提现  非饮料   饼干糕点
# 4      68g好丽友巧克力派2枚    2017/1/9 21:38  C  已出货未退款  已提现  非饮料   饼干糕点
# ...             ...               ... ..     ...  ...  ...    ...
# 70685     20g洽洽每日坚果  2017/11/19 10:41  C  已出货未退款  已提现  非饮料   坚果炒货
# 70686          商品36  2017/11/15 15:16  C  已出货未退款  已提现  非饮料     其他
# 70687    80g粤光宝盒芒果干    2017/12/4 6:47  A  已出货未退款  已提现  非饮料  蜜饯/果干
# 70688          商品21  2017/12/10 16:18  C  已出货未退款  已提现  非饮料     其他
# 70689          商品21  2017/12/10 21:29  E  已出货未退款  已提现  非饮料     其他
#
# [70690 rows x 11 columns]

# %%
data.T
# Out:
#                               0                             1      \
# 订单号   DD201708167493663618499909784  DD20170816749368329675770932
# 设备ID                E43A6E078A07631               E43A6E078A07631
# 应付金额                                                          4.5
# 实际金额                            4.5                           4.5
# 商品                     68g好丽友巧克力派2枚                  68g好丽友巧克力派2枚
# 支付时间                  2017/1/1 0:53                2017/1/2 20:58
# 地点                                D                             D
# 状态                           已出货未退款                        已出货未退款
# 提现                              已提现                           已提现
# 大类                              非饮料                           非饮料
# 二级类                            饼干糕点                          饼干糕点
#
#                                 2                              3      \
# 订单号   DD20170816749300229112037656709  DD201708167493529849068514902
# 设备ID                  E43A6E078A06874                E43A6E078A04228
# 应付金额                              4.5                              4
# 实际金额                              4.5                              4
# 商品                       68g好丽友巧克力派2枚                   68g好丽友巧克力派2枚
# 支付时间                    2017/1/3 1:53                 2017/1/8 20:22
# 地点                                  E                              C
# 状态                             已出货未退款                         已出货未退款
# 提现                                已提现                            已提现
# 大类                                非饮料                            非饮料
# 二级类                              饼干糕点                           饼干糕点
#
#                               4                              5      \
# 订单号   DD201708167493876353091909391  DD201708167493682323795309392
# 设备ID                E43A6E078A04228                E43A6E078A07631
# 应付金额                             14                            4.5
# 实际金额                             14                            4.5
# 商品                     68g好丽友巧克力派2枚                   68g好丽友巧克力派2枚
# 支付时间                 2017/1/9 21:38                2017/1/15 22:38
# 地点                                C                              D
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                            饼干糕点                           饼干糕点
#
#                               6                              7      \
# 订单号   DD201708167493378243726136547  DD201708167493602891682850302
# 设备ID                E43A6E078A06874                E43A6E078A06874
# 应付金额                             14                            4.5
# 实际金额                             14                            4.5
# 商品                     68g好丽友巧克力派2枚                   68g好丽友巧克力派2枚
# 支付时间                2017/1/29 11:15                2017/3/29 13:17
# 地点                                E                              E
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                            饼干糕点                           饼干糕点
#
#                              8                                9      ...  \
# 订单号   DD20170816749354740197576134  DD20170816749300201200671606871  ...
# 设备ID               E43A6E078A06874                  E43A6E078A06874  ...
# 应付金额                           4.5                              4.5  ...
# 实际金额                           4.5                              4.5  ...
# 商品                    68g好丽友巧克力派2枚                     68g好丽友巧克力派2枚  ...
# 支付时间               2017/3/29 17:11                   2017/4/2 21:21  ...
# 地点                               E                                E  ...
# 状态                          已出货未退款                           已出货未退款  ...
# 提现                             已提现                              已提现  ...
# 大类                             非饮料                              非饮料  ...
# 二级类                           饼干糕点                             饼干糕点  ...
#
#                               70680                          70681  \
# 订单号   DD201708167493435737847961442  DD201708167493890918161958157
# 设备ID                E43A6E078A04172                E43A6E078A06874
# 应付金额                              2                            5.5
# 实际金额                              2                            5.5
# 商品                   越南LIPO奶味面包干10g                       60g溜溜九制梅
# 支付时间                2017/10/8 16:24               2017/10/10 17:18
# 地点                                A                              E
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                            饼干糕点                          蜜饯/果干
#
#                               70682                          70683  \
# 订单号   DD201708167493584820073836344  DD201708167493773559548628425
# 设备ID                E43A6E078A04172                E43A6E078A04134
# 应付金额                              6                              5
# 实际金额                              6                              5
# 商品                     60g湖湘贡手撕鸭脖原味                      90g顺宝九制杨梅
# 支付时间               2017/10/23 14:17                2017/11/1 12:33
# 地点                                A                              B
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                        肉干/豆制品/蛋                          蜜饯/果干
#
#                               70684                          70685  \
# 订单号   DD201708167493577208345166776  DD201708167493878114605918673
# 设备ID                E43A6E078A04172                E43A6E078A04228
# 应付金额                            5.5                             11
# 实际金额                            5.5                             11
# 商品                        20g洽洽每日坚果                      20g洽洽每日坚果
# 支付时间                2017/11/1 22:36               2017/11/19 10:41
# 地点                                A                              C
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                            坚果炒货                           坚果炒货
#
#                               70686                          70687  \
# 订单号   DD201708167493690426013200961  DD201708167493774605081730209
# 设备ID                E43A6E078A04228                E43A6E078A04172
# 应付金额                              4                             11
# 实际金额                              4                             11
# 商品                             商品36                     80g粤光宝盒芒果干
# 支付时间               2017/11/15 15:16                 2017/12/4 6:47
# 地点                                C                              A
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                              其他                          蜜饯/果干
#
#                               70688                          70689
# 订单号   DD2017041716541957D1BE9289A69  DD2017041716040483BC6D38F8F83
# 设备ID                E43A6E078A04228                E43A6E078A06874
# 应付金额                            0.1                            0.1
# 实际金额                            0.1                            0.1
# 商品                             商品21                           商品21
# 支付时间               2017/12/10 16:18               2017/12/10 21:29
# 地点                                C                              E
# 状态                           已出货未退款                         已出货未退款
# 提现                              已提现                            已提现
# 大类                              非饮料                            非饮料
# 二级类                              其他                             其他
#
# [11 rows x 70690 columns]

# %%
data.to_excel('./data.xlsx')

# %%
data.duplicated().value_counts()
# Out:
# False    70675
# True        15
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#                                    订单号             设备ID 应付金额 实际金额  \
# 0        DD201708167493663618499909784  E43A6E078A07631       4.5
# 1         DD20170816749368329675770932  E43A6E078A07631  4.5  4.5
# 2      DD20170816749300229112037656709  E43A6E078A06874  4.5  4.5
# 3        DD201708167493529849068514902  E43A6E078A04228    4    4
# 4        DD201708167493876353091909391  E43A6E078A04228   14   14
# ...                                ...              ...  ...  ...
# 70685    DD201708167493878114605918673  E43A6E078A04228   11   11
# 70686    DD201708167493690426013200961  E43A6E078A04228    4    4
# 70687    DD201708167493774605081730209  E43A6E078A04172   11   11
# 70688    DD2017041716541957D1BE9289A69  E43A6E078A04228  0.1  0.1
# 70689    DD2017041716040483BC6D38F8F83  E43A6E078A06874  0.1  0.1
#
#                  商品              支付时间 地点      状态   提现   大类    二级类
# 0      68g好丽友巧克力派2枚     2017/1/1 0:53  D  已出货未退款  已提现  非饮料   饼干糕点
# 1      68g好丽友巧克力派2枚    2017/1/2 20:58  D  已出货未退款  已提现  非饮料   饼干糕点
# 2      68g好丽友巧克力派2枚     2017/1/3 1:53  E  已出货未退款  已提现  非饮料   饼干糕点
# 3      68g好丽友巧克力派2枚    2017/1/8 20:22  C  已出货未退款  已提现  非饮料   饼干糕点
# 4      68g好丽友巧克力派2枚    2017/1/9 21:38  C  已出货未退款  已提现  非饮料   饼干糕点
# ...             ...               ... ..     ...  ...  ...    ...
# 70685     20g洽洽每日坚果  2017/11/19 10:41  C  已出货未退款  已提现  非饮料   坚果炒货
# 70686          商品36  2017/11/15 15:16  C  已出货未退款  已提现  非饮料     其他
# 70687    80g粤光宝盒芒果干    2017/12/4 6:47  A  已出货未退款  已提现  非饮料  蜜饯/果干
# 70688          商品21  2017/12/10 16:18  C  已出货未退款  已提现  非饮料     其他
# 70689          商品21  2017/12/10 21:29  E  已出货未退款  已提现  非饮料     其他
#
# [70675 rows x 11 columns]

# %%
outputfile=('./dataoutput.xlsx')
data=pd.merge(data1,data2,on='商品')
data.describe().to_excel(outputfile, index=True)

# %%
num = pd.DataFrame(data,columns = [ '应付金额'])
left=num.mean()-3*num.std()
right=num.mean()+3*num.std()
new_num=num[(left>num)&(num>right)]
print(new_num)
# Out:
#       应付金额
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 70685  NaN
# 70686  NaN
# 70687  NaN
# 70688  NaN
# 70689  NaN
#
# [70690 rows x 1 columns]

# %%
print(data.isnull())
# Out:
#          订单号   设备ID   应付金额   实际金额     商品   支付时间     地点     状态     提现     大类  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 70685  False  False  False  False  False  False  False  False  False  False
# 70686  False  False  False  False  False  False  False  False  False  False
# 70687  False  False  False  False  False  False  False  False  False  False
# 70688  False  False  False  False  False  False  False  False  False  False
# 70689  False  False  False  False  False  False  False  False  False  False
#
#          二级类
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 70685  False
# 70686  False
# 70687  False
# 70688  False
# 70689  False
#
# [70690 rows x 11 columns]

# %%
print(data.isnull().any())
# Out:
# 订单号     False
# 设备ID    False
# 应付金额     True
# 实际金额     True
# 商品      False
# 支付时间    False
# 地点      False
# 状态      False
# 提现      False
# 大类      False
# 二级类     False
# dtype: bool

# %%
print(data[data.isnull().values==True])
# Out:
#                                   订单号             设备ID 应付金额 实际金额  \
# 15965    DD20170816749328626957419562  E43A6E078A06874  NaN  NaN
# 15965    DD20170816749328626957419562  E43A6E078A06874  NaN  NaN
# 16208   DD201708167493462771484701176  E43A6E078A04228  NaN  NaN
# 16208   DD201708167493462771484701176  E43A6E078A04228  NaN  NaN
# 19064   DD201708167493655413087619908  E43A6E078A04134  NaN  NaN
# 19064   DD201708167493655413087619908  E43A6E078A04134  NaN  NaN
# 69132  DD2017081674930182758918544179  E43A6E078A06874  NaN  NaN
# 69132  DD2017081674930182758918544179  E43A6E078A06874  NaN  NaN
# 69136   DD201708167493745038969181186  E43A6E078A04134  NaN  NaN
# 69136   DD201708167493745038969181186  E43A6E078A04134  NaN  NaN
# 69158   DD201708167493116318578183853  E43A6E078A04228  NaN  NaN
# 69158   DD201708167493116318578183853  E43A6E078A04228  NaN  NaN
#
#                         商品              支付时间 地点      状态   提现   大类   二级类
# 15965                   红牛   2017/6/13 23:39  E  已出货未退款  已提现   饮料  功能饮料
# 15965                   红牛   2017/6/13 23:39  E  已出货未退款  已提现   饮料  功能饮料
# 16208                   红牛   2017/9/17 12:09  C  已出货未退款  已提现   饮料  功能饮料
# 16208                   红牛   2017/9/17 12:09  C  已出货未退款  已提现   饮料  功能饮料
# 19064        268ml雀巢咖啡丝滑拿铁   2017/10/29 8:50  B  已出货未退款  已提现   饮料    咖啡
# 19064        268ml雀巢咖啡丝滑拿铁   2017/10/29 8:50  B  已出货未退款  已提现   饮料    咖啡
# 69132  180g统一满汉全席台式半筋半肉牛肉面    2017/8/6 18:06  E  已出货未退款  已提现  非饮料  方便速食
# 69132  180g统一满汉全席台式半筋半肉牛肉面    2017/8/6 18:06  E  已出货未退款  已提现  非饮料  方便速食
# 69136  180g统一满汉全席台式半筋半肉牛肉面   2017/9/23 15:17  B  已出货未退款  已提现  非饮料  方便速食
# 69136  180g统一满汉全席台式半筋半肉牛肉面   2017/9/23 15:17  B  已出货未退款  已提现  非饮料  方便速食
# 69158  180g统一满汉全席台式半筋半肉牛肉面  2017/11/20 10:18  C  已出货未退款  已提现  非饮料  方便速食
# 69158  180g统一满汉全席台式半筋半肉牛肉面  2017/11/20 10:18  C  已出货未退款  已提现  非饮料  方便速食

# %%
data.dropna(how='any', axis=0,inplace=True)
print(data.isnull().any())
# Out:
# 订单号     False
# 设备ID    False
# 应付金额    False
# 实际金额    False
# 商品      False
# 支付时间    False
# 地点      False
# 状态      False
# 提现      False
# 大类      False
# 二级类     False
# dtype: bool

# %%
data.to_excel('./data3.xlsx')
